# %%
a = 2
b = "2"
print(" a = ", a, "type = ", type(a))
print(" b = ", b, "type = ", type(b))
# Out:
#  a =  2 type =  <class 'int'>
#  b =  2 type =  <class 'str'>

# %%
print('execution starts here')
print("converting a to string and then adding to b, a + b = ", str(a) + b)
print("converting b to int and then adding to a, a + b = ", a + int(b))
print("execution ends here")
# Out:
# execution starts here
# converting a to string and then adding to b, a + b =  22
# converting b to int and then adding to a, a + b =  4
# execution ends here

# %% [markdown]
# echo "# python_basic_variable" >> README.md
# git init
# git add README.md
# git commit -m "first commit"
# git branch -M main
# git remote add origin https://github.com/VarnikaGulhane1/python_basic_variable.git
# git push -u origin main
